# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 735

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    city_url = url + "&q=" + city.replace(" ","+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
# Run API request for each city
    try:
        city_weather = requests.get(city_url).json()

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_weatherDescription = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert timestamps
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Weather Description": city_weatherDescription,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

city_data_df = pd.DataFrame(city_data)
output_data_file = "weather_data/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
city_data_df.head(10)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port hardy
# Processing Record 2 of Set 1 | sembe
# Processing Record 3 of Set 1 | katsuura
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | constitucion
# Processing Record 7 of Set 1 | luderitz
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | alvaraes
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | la vega
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | usinsk
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | touba
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 1 | turukhansk
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | zheleznogorsk
# Processing Record 25 of Set 1 | adeje
# Processing Record 26 of Set 1 | buraydah
# Processing Record 27 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 1 | esso
# Processing Record 29 of Set 1 | puerto escondido
# Processing Record 30 of Set 1 | asau
# Processing Record 31 of Set 1 | vardo
# Processing Record 32 of Set 1 | los algarrobos
# Processing Record 33 of Set 1 | myaundzha
# Processing Record 34 of Set 1 | nortelandia
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | makurdi
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | hovd
# Processing Record 44 of Set 1 | juneau
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | tadine
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | eureka
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | narsaq
# Processing Record 1 of Set 2 | mataura
# Processing Record 2 of Set 2 | omsukchan
# Processing Record 3 of Set 2 | sungurlu
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | kanye
# Processing Record 6 of Set 2 | araouane
# Processing Record 7 of Set 2 | tromso
# Processing Record 8 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | taoudenni
# Processing Record 11 of Set 2 | nome
# Processing Record 12 of Set 2 | tual
# Processing Record 13 of Set 2 | sarankhola
# Processing Record 14 of Set 2 | san luis
# Processing Record 15 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 2 | kalaleh
# Processing Record 17 of Set 2 | chodziez
# Processing Record 18 of Set 2 | deputatskiy
# Processing Record 19 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 2 | qingdao
# Processing Record 21 of Set 2 | soe
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | mabaruma
# Processing Record 24 of Set 2 | calabasas
# Processing Record 25 of Set 2 | makueni
# Processing Record 26 of Set 2 | manggar
# Processing Record 27 of Set 2 | breytovo
# Processing Record 28 of Set 2 | quatre cocos
# Processing Record 29 of Set 2 | port elizabeth
# Processing Record 30 of Set 2 | lorengau
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | miquelon
# Processing Record 34 of Set 2 | mochicahui
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | albany
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | fairbanks
# Processing Record 41 of Set 2 | manavalakurichi
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | asyut
# Processing Record 44 of Set 2 | qasigiannguit
# Processing Record 45 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 2 | tacuarembo
# Processing Record 47 of Set 2 | faanui
# Processing Record 48 of Set 2 | tacotalpa
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | zhigansk
# Processing Record 2 of Set 3 | betafo
# Processing Record 3 of Set 3 | iskateley
# Processing Record 4 of Set 3 | naron
# Processing Record 5 of Set 3 | pangnirtung
# Processing Record 6 of Set 3 | puerto ayora
# Processing Record 7 of Set 3 | manokwari
# Processing Record 8 of Set 3 | ancud
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | hervey bay
# Processing Record 13 of Set 3 | narasapur
# Processing Record 14 of Set 3 | sayan
# Processing Record 15 of Set 3 | mayo
# Processing Record 16 of Set 3 | san cosme y damian
# Processing Record 17 of Set 3 | tabas
# Processing Record 18 of Set 3 | kruisfontein
# Processing Record 19 of Set 3 | camacha
# Processing Record 20 of Set 3 | nayoro
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | medea
# Processing Record 24 of Set 3 | yar-sale
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | rawson
# Processing Record 28 of Set 3 | hearst
# Processing Record 29 of Set 3 | shimoda
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | talkha
# Processing Record 32 of Set 3 | bud
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | constantine
# Processing Record 35 of Set 3 | zarubino
# Processing Record 36 of Set 3 | labuhan
# Processing Record 37 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 38 of Set 3 | victoria
# Processing Record 39 of Set 3 | tarko-sale
# Processing Record 40 of Set 3 | haines junction
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | kalemie
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | ushuaia
# Processing Record 47 of Set 3 | beloha
# Processing Record 48 of Set 3 | grindavik
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | saldanha
# Processing Record 1 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 4 | silifke
# Processing Record 3 of Set 4 | thompson
# Processing Record 4 of Set 4 | samfya
# Processing Record 5 of Set 4 | clyde river
# Processing Record 6 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 4 | aykhal
# Processing Record 8 of Set 4 | bandarbeyla
# Processing Record 9 of Set 4 | guozhen
# Processing Record 10 of Set 4 | ulladulla
# Processing Record 11 of Set 4 | dingle
# Processing Record 12 of Set 4 | hailar
# Processing Record 13 of Set 4 | olafsvik
# Processing Record 14 of Set 4 | keita
# Processing Record 15 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | bakau
# Processing Record 18 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 4 | grand gaube
# Processing Record 21 of Set 4 | ahipara
# Processing Record 22 of Set 4 | verkhoyansk
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | hastings
# Processing Record 25 of Set 4 | lakes entrance
# Processing Record 26 of Set 4 | ippy
# Processing Record 27 of Set 4 | buwenge
# Processing Record 28 of Set 4 | mount isa
# Processing Record 29 of Set 4 | kachikau
# City not found. Skipping...
# Processing Record 30 of Set 4 | wattegama
# Processing Record 31 of Set 4 | bambous virieux
# Processing Record 32 of Set 4 | canberra
# Processing Record 33 of Set 4 | blind river
# Processing Record 34 of Set 4 | ballina
# Processing Record 35 of Set 4 | mana
# Processing Record 36 of Set 4 | torbay
# Processing Record 37 of Set 4 | fortuna
# Processing Record 38 of Set 4 | trelew
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | hobart
# Processing Record 41 of Set 4 | komsomolskiy
# Processing Record 42 of Set 4 | faya
# Processing Record 43 of Set 4 | hilo
# Processing Record 44 of Set 4 | ambilobe
# Processing Record 45 of Set 4 | touros
# Processing Record 46 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 47 of Set 4 | senno
# Processing Record 48 of Set 4 | hualmay
# Processing Record 49 of Set 4 | krutinka
# Processing Record 50 of Set 4 | minbu
# Processing Record 1 of Set 5 | harper
# Processing Record 2 of Set 5 | mwanza
# Processing Record 3 of Set 5 | cortland
# Processing Record 4 of Set 5 | hofn
# Processing Record 5 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 5 | severo-kurilsk
# Processing Record 7 of Set 5 | javanrud
# Processing Record 8 of Set 5 | tasiilaq
# Processing Record 9 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 5 | elizabeth city
# Processing Record 11 of Set 5 | nsanje
# Processing Record 12 of Set 5 | xingyi
# Processing Record 13 of Set 5 | manjacaze
# Processing Record 14 of Set 5 | namibe
# Processing Record 15 of Set 5 | aqtobe
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | umm kaddadah
# Processing Record 18 of Set 5 | upernavik
# Processing Record 19 of Set 5 | aketi
# Processing Record 20 of Set 5 | ibra
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | malanje
# Processing Record 23 of Set 5 | port antonio
# Processing Record 24 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 5 | sitka
# Processing Record 26 of Set 5 | sayyan
# Processing Record 27 of Set 5 | kupang
# Processing Record 28 of Set 5 | cap malheureux
# Processing Record 29 of Set 5 | verkhoturye
# Processing Record 30 of Set 5 | kushima
# Processing Record 31 of Set 5 | filadelfia
# Processing Record 32 of Set 5 | asilah
# Processing Record 33 of Set 5 | nouadhibou
# Processing Record 34 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 5 | linqiong
# Processing Record 36 of Set 5 | saint-francois
# Processing Record 37 of Set 5 | roma
# Processing Record 38 of Set 5 | bluff
# Processing Record 39 of Set 5 | dunedin
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | burkhala
# City not found. Skipping...
# Processing Record 42 of Set 5 | nara
# Processing Record 43 of Set 5 | kaitangata
# Processing Record 44 of Set 5 | saint-augustin
# Processing Record 45 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 5 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 5 | airai
# Processing Record 49 of Set 5 | along
# Processing Record 50 of Set 5 | vila velha
# Processing Record 1 of Set 6 | pasni
# Processing Record 2 of Set 6 | westport
# Processing Record 3 of Set 6 | houma
# Processing Record 4 of Set 6 | adre
# Processing Record 5 of Set 6 | seydisehir
# Processing Record 6 of Set 6 | lunenburg
# Processing Record 7 of Set 6 | chicama
# Processing Record 8 of Set 6 | casablanca
# Processing Record 9 of Set 6 | kerouane
# Processing Record 10 of Set 6 | saint george
# Processing Record 11 of Set 6 | changli
# Processing Record 12 of Set 6 | yugo-kamskiy
# Processing Record 13 of Set 6 | kirovsk
# Processing Record 14 of Set 6 | davidson
# Processing Record 15 of Set 6 | honiara
# Processing Record 16 of Set 6 | santa fe
# Processing Record 17 of Set 6 | wodzislaw slaski
# Processing Record 18 of Set 6 | ketchikan
# Processing Record 19 of Set 6 | la paz
# Processing Record 20 of Set 6 | mogadishu
# Processing Record 21 of Set 6 | bubaque
# Processing Record 22 of Set 6 | wawa
# Processing Record 23 of Set 6 | iqaluit
# Processing Record 24 of Set 6 | alofi
# Processing Record 25 of Set 6 | baloda bazar
# Processing Record 26 of Set 6 | srednekolymsk
# Processing Record 27 of Set 6 | aklavik
# Processing Record 28 of Set 6 | nikolskoye
# Processing Record 29 of Set 6 | korla
# Processing Record 30 of Set 6 | vestmannaeyjar
# Processing Record 31 of Set 6 | acari
# Processing Record 32 of Set 6 | ivanteyevka
# Processing Record 33 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 34 of Set 6 | te anau
# Processing Record 35 of Set 6 | berwick
# Processing Record 36 of Set 6 | san patricio
# Processing Record 37 of Set 6 | cururupu
# Processing Record 38 of Set 6 | narrabri
# Processing Record 39 of Set 6 | kailua
# Processing Record 40 of Set 6 | geraldton
# Processing Record 41 of Set 6 | darnah
# Processing Record 42 of Set 6 | cabo san lucas
# Processing Record 43 of Set 6 | xichang
# Processing Record 44 of Set 6 | krabi
# Processing Record 45 of Set 6 | lasa
# Processing Record 46 of Set 6 | caravelas
# Processing Record 47 of Set 6 | sterling
# Processing Record 48 of Set 6 | lebu
# Processing Record 49 of Set 6 | walvis bay
# Processing Record 50 of Set 6 | manaure
# Processing Record 1 of Set 7 | hendrina
# Processing Record 2 of Set 7 | mindelo
# Processing Record 3 of Set 7 | blagoyevo
# Processing Record 4 of Set 7 | pinhao
# Processing Record 5 of Set 7 | portsmouth
# Processing Record 6 of Set 7 | nantucket
# Processing Record 7 of Set 7 | borogontsy
# Processing Record 8 of Set 7 | koroni
# Processing Record 9 of Set 7 | byron bay
# Processing Record 10 of Set 7 | husavik
# Processing Record 11 of Set 7 | mormugao
# Processing Record 12 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 13 of Set 7 | muswellbrook
# Processing Record 14 of Set 7 | port macquarie
# Processing Record 15 of Set 7 | diu
# Processing Record 16 of Set 7 | maceio
# Processing Record 17 of Set 7 | puerto leguizamo
# Processing Record 18 of Set 7 | bolama
# Processing Record 19 of Set 7 | laguna
# Processing Record 20 of Set 7 | mazatlan
# Processing Record 21 of Set 7 | khatanga
# Processing Record 22 of Set 7 | naze
# Processing Record 23 of Set 7 | san cristobal
# Processing Record 24 of Set 7 | waipawa
# Processing Record 25 of Set 7 | paraiso
# Processing Record 26 of Set 7 | ostrovnoy
# Processing Record 27 of Set 7 | pevek
# Processing Record 28 of Set 7 | saryozek
# Processing Record 29 of Set 7 | neyshabur
# Processing Record 30 of Set 7 | havre-saint-pierre
# Processing Record 31 of Set 7 | nyurba
# Processing Record 32 of Set 7 | oussouye
# Processing Record 33 of Set 7 | mamakan
# Processing Record 34 of Set 7 | devonport
# Processing Record 35 of Set 7 | kununurra
# Processing Record 36 of Set 7 | amapa
# Processing Record 37 of Set 7 | hambantota
# Processing Record 38 of Set 7 | teguldet
# Processing Record 39 of Set 7 | avera
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | aktas
# Processing Record 42 of Set 7 | whitianga
# Processing Record 43 of Set 7 | esperance
# Processing Record 44 of Set 7 | lalmohan
# Processing Record 45 of Set 7 | itarema
# Processing Record 46 of Set 7 | itaituba
# Processing Record 47 of Set 7 | itamaraca
# Processing Record 48 of Set 7 | eskisehir
# Processing Record 49 of Set 7 | southbridge
# Processing Record 50 of Set 7 | luena
# Processing Record 1 of Set 8 | dikson
# Processing Record 2 of Set 8 | mae hong son
# Processing Record 3 of Set 8 | skegness
# Processing Record 4 of Set 8 | turgenevo
# Processing Record 5 of Set 8 | uttaradit
# Processing Record 6 of Set 8 | atbasar
# Processing Record 7 of Set 8 | calama
# Processing Record 8 of Set 8 | grajau
# Processing Record 9 of Set 8 | talnakh
# Processing Record 10 of Set 8 | chapais
# Processing Record 11 of Set 8 | palauig
# Processing Record 12 of Set 8 | banikoara
# Processing Record 13 of Set 8 | alice springs
# Processing Record 14 of Set 8 | vila franca do campo
# Processing Record 15 of Set 8 | sungai padi
# Processing Record 16 of Set 8 | kloulklubed
# Processing Record 17 of Set 8 | emerald
# Processing Record 18 of Set 8 | alta floresta
# Processing Record 19 of Set 8 | great bend
# Processing Record 20 of Set 8 | chokurdakh
# Processing Record 21 of Set 8 | beyneu
# Processing Record 22 of Set 8 | shingu
# Processing Record 23 of Set 8 | vanavara
# Processing Record 24 of Set 8 | rocha
# Processing Record 25 of Set 8 | sohbatpur
# Processing Record 26 of Set 8 | burla
# Processing Record 27 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 28 of Set 8 | presidente epitacio
# Processing Record 29 of Set 8 | jackson
# Processing Record 30 of Set 8 | columbus
# Processing Record 31 of Set 8 | ozernovskiy
# Processing Record 32 of Set 8 | goderich
# Processing Record 33 of Set 8 | tiarei
# Processing Record 34 of Set 8 | aleysk
# Processing Record 35 of Set 8 | arkhangelsk
# Processing Record 36 of Set 8 | vitoria do mearim
# Processing Record 37 of Set 8 | canaman
# Processing Record 38 of Set 8 | jumla
# Processing Record 39 of Set 8 | strezhevoy
# Processing Record 40 of Set 8 | christchurch
# Processing Record 41 of Set 8 | hayden
# Processing Record 42 of Set 8 | shurob
# Processing Record 43 of Set 8 | leningradskiy
# Processing Record 44 of Set 8 | gongzhuling
# Processing Record 45 of Set 8 | tecoanapa
# Processing Record 46 of Set 8 | muisne
# Processing Record 47 of Set 8 | hamilton
# Processing Record 48 of Set 8 | yulara
# Processing Record 49 of Set 8 | oktyabrskoye
# Processing Record 50 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 1 of Set 9 | marzuq
# Processing Record 2 of Set 9 | pak phanang
# Processing Record 3 of Set 9 | broome
# Processing Record 4 of Set 9 | blora
# Processing Record 5 of Set 9 | fukue
# Processing Record 6 of Set 9 | leo
# Processing Record 7 of Set 9 | massakory
# Processing Record 8 of Set 9 | hokitika
# Processing Record 9 of Set 9 | dale
# Processing Record 10 of Set 9 | aksha
# Processing Record 11 of Set 9 | birjand
# Processing Record 12 of Set 9 | jasper
# Processing Record 13 of Set 9 | les cayes
# Processing Record 14 of Set 9 | colquechaca
# Processing Record 15 of Set 9 | corpus christi
# Processing Record 16 of Set 9 | nha trang
# Processing Record 17 of Set 9 | ilulissat
# Processing Record 18 of Set 9 | bafoulabe
# Processing Record 19 of Set 9 | tabuk
# Processing Record 20 of Set 9 | perbaungan
# Processing Record 21 of Set 9 | diamantino
# Processing Record 22 of Set 9 | kretinga
# Processing Record 23 of Set 9 | conakry
# Processing Record 24 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 9 | senanga
# Processing Record 26 of Set 9 | esmeraldas
# Processing Record 27 of Set 9 | nanortalik
# Processing Record 28 of Set 9 | grand-santi
# Processing Record 29 of Set 9 | nagykanizsa
# Processing Record 30 of Set 9 | kvarkeno
# Processing Record 31 of Set 9 | great yarmouth
# Processing Record 32 of Set 9 | codrington
# Processing Record 33 of Set 9 | salalah
# Processing Record 34 of Set 9 | wajima
# Processing Record 35 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 36 of Set 9 | wichita falls
# Processing Record 37 of Set 9 | cayenne
# Processing Record 38 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 9 | lazaro cardenas
# Processing Record 40 of Set 9 | port lincoln
# Processing Record 41 of Set 9 | oga
# Processing Record 42 of Set 9 | belmonte
# Processing Record 43 of Set 9 | pirgos
# Processing Record 44 of Set 9 | gamba
# Processing Record 45 of Set 9 | aktau
# Processing Record 46 of Set 9 | weihe
# Processing Record 47 of Set 9 | tessalit
# Processing Record 48 of Set 9 | alyangula
# Processing Record 49 of Set 9 | la asuncion
# Processing Record 50 of Set 9 | flinders
# Processing Record 1 of Set 10 | batagay
# Processing Record 2 of Set 10 | churapcha
# Processing Record 3 of Set 10 | severodvinsk
# Processing Record 4 of Set 10 | asekeyevo
# Processing Record 5 of Set 10 | belle fourche
# Processing Record 6 of Set 10 | orocue
# Processing Record 7 of Set 10 | tulum
# Processing Record 8 of Set 10 | peniche
# Processing Record 9 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 10 of Set 10 | tahe
# Processing Record 11 of Set 10 | poum
# Processing Record 12 of Set 10 | ontario
# Processing Record 13 of Set 10 | samarai
# Processing Record 14 of Set 10 | bonthe
# Processing Record 15 of Set 10 | lubango
# Processing Record 16 of Set 10 | kitgum
# Processing Record 17 of Set 10 | hobyo
# Processing Record 18 of Set 10 | vostok
# Processing Record 19 of Set 10 | rjukan
# Processing Record 20 of Set 10 | tautira
# Processing Record 21 of Set 10 | pathein
# Processing Record 22 of Set 10 | okha
# Processing Record 23 of Set 10 | muroto
# Processing Record 24 of Set 10 | northam
# Processing Record 25 of Set 10 | bridgend
# Processing Record 26 of Set 10 | toyooka
# Processing Record 27 of Set 10 | abu dhabi
# Processing Record 28 of Set 10 | kostomuksha
# Processing Record 29 of Set 10 | los altos
# Processing Record 30 of Set 10 | zinder
# Processing Record 31 of Set 10 | maltahohe
# Processing Record 32 of Set 10 | nelson bay
# Processing Record 33 of Set 10 | udachnyy
# Processing Record 34 of Set 10 | binga
# Processing Record 35 of Set 10 | san jose
# Processing Record 36 of Set 10 | saint-joseph
# Processing Record 37 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 10 | zalantun
# Processing Record 39 of Set 10 | kokopo
# Processing Record 40 of Set 10 | hofgeismar
# Processing Record 41 of Set 10 | pafos
# Processing Record 42 of Set 10 | sampit
# Processing Record 43 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 44 of Set 10 | khani
# Processing Record 45 of Set 10 | coquimbo
# Processing Record 46 of Set 10 | umm lajj
# Processing Record 47 of Set 10 | barrhead
# Processing Record 48 of Set 10 | seydi
# Processing Record 49 of Set 10 | ussel
# Processing Record 50 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 1 of Set 11 | bathsheba
# Processing Record 2 of Set 11 | nicoya
# Processing Record 3 of Set 11 | bileca
# Processing Record 4 of Set 11 | binghamton
# Processing Record 5 of Set 11 | santa maria
# Processing Record 6 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 11 | praia da vitoria
# Processing Record 8 of Set 11 | tahoua
# Processing Record 9 of Set 11 | atambua
# Processing Record 10 of Set 11 | atar
# Processing Record 11 of Set 11 | elat
# Processing Record 12 of Set 11 | sioux lookout
# Processing Record 13 of Set 11 | roald
# Processing Record 14 of Set 11 | praia
# Processing Record 15 of Set 11 | iglesias
# Processing Record 16 of Set 11 | russell
# Processing Record 17 of Set 11 | kankon
# Processing Record 18 of Set 11 | nyakahanga
# Processing Record 19 of Set 11 | songea
# Processing Record 20 of Set 11 | belyy yar
# Processing Record 21 of Set 11 | uyar
# Processing Record 22 of Set 11 | mackay
# Processing Record 23 of Set 11 | west odessa
# Processing Record 24 of Set 11 | parral
# Processing Record 25 of Set 11 | potiskum
# Processing Record 26 of Set 11 | mporokoso
# Processing Record 27 of Set 11 | portland
# Processing Record 28 of Set 11 | los llanos de aridane
# Processing Record 29 of Set 11 | kutum
# Processing Record 30 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 31 of Set 11 | kalmunai
# Processing Record 32 of Set 11 | broken hill
# Processing Record 33 of Set 11 | roebourne
# Processing Record 34 of Set 11 | los banos
# Processing Record 35 of Set 11 | kiama
# Processing Record 36 of Set 11 | chenzhou
# Processing Record 37 of Set 11 | outjo
# Processing Record 38 of Set 11 | maple creek
# Processing Record 39 of Set 11 | aksarka
# Processing Record 40 of Set 11 | mandleshwar
# Processing Record 41 of Set 11 | aswan
# Processing Record 42 of Set 11 | kendari
# Processing Record 43 of Set 11 | oranjestad
# Processing Record 44 of Set 11 | cairns
# Processing Record 45 of Set 11 | isangel
# Processing Record 46 of Set 11 | lata
# Processing Record 47 of Set 11 | nalut
# Processing Record 48 of Set 11 | bilibino
# Processing Record 49 of Set 11 | namatanai
# Processing Record 50 of Set 11 | mansa
# Processing Record 1 of Set 12 | raga
# Processing Record 2 of Set 12 | shirokiy
# Processing Record 3 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 4 of Set 12 | ndele
# Processing Record 5 of Set 12 | chiang klang
# Processing Record 6 of Set 12 | melong
# Processing Record 7 of Set 12 | pingliang
# Processing Record 8 of Set 12 | kahului
# Processing Record 9 of Set 12 | rawlins
# Processing Record 10 of Set 12 | uribia
# Processing Record 11 of Set 12 | mutoko
# Processing Record 12 of Set 12 | yumen
# Processing Record 13 of Set 12 | buy
# Processing Record 14 of Set 12 | dicabisagan
# Processing Record 15 of Set 12 | chodavaram
# Processing Record 16 of Set 12 | hay river
# Processing Record 17 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 12 | villarrica
# Processing Record 19 of Set 12 | santa cruz
# Processing Record 20 of Set 12 | ravar
# Processing Record 21 of Set 12 | tambovka
# Processing Record 22 of Set 12 | tutoia
# Processing Record 23 of Set 12 | ratnagiri
# Processing Record 24 of Set 12 | chase
# Processing Record 25 of Set 12 | sabratah
# Processing Record 26 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 12 | heishan
# Processing Record 28 of Set 12 | kemin
# Processing Record 29 of Set 12 | xuddur
# Processing Record 30 of Set 12 | arawa
# Processing Record 31 of Set 12 | noumea
# Processing Record 32 of Set 12 | boguchar
# Processing Record 33 of Set 12 | havelock
# Processing Record 34 of Set 12 | lumeje
# Processing Record 35 of Set 12 | dawlatabad
# Processing Record 36 of Set 12 | bayir
# Processing Record 37 of Set 12 | mookane
# Processing Record 38 of Set 12 | canchungo
# Processing Record 39 of Set 12 | stepnyak
# Processing Record 40 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 41 of Set 12 | yining
# Processing Record 42 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 12 | plettenberg bay
# Processing Record 44 of Set 12 | wilmington
# Processing Record 45 of Set 12 | bull savanna
# Processing Record 46 of Set 12 | padang
# Processing Record 47 of Set 12 | bowen
# Processing Record 48 of Set 12 | mocuba
# Processing Record 49 of Set 12 | kinablangan
# Processing Record 50 of Set 12 | huarmey
# Processing Record 1 of Set 13 | turan
# Processing Record 2 of Set 13 | mirnyy
# Processing Record 3 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 13 | maniwaki
# Processing Record 5 of Set 13 | manitouwadge
# Processing Record 6 of Set 13 | santa isabel do rio negro
# Processing Record 7 of Set 13 | camopi
# Processing Record 8 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 13 | zabolotovka
# Processing Record 10 of Set 13 | vironia
# City not found. Skipping...
# Processing Record 11 of Set 13 | jilmah
# City not found. Skipping...
# Processing Record 12 of Set 13 | belaya gora
# Processing Record 13 of Set 13 | pochutla
# Processing Record 14 of Set 13 | dwarka
# Processing Record 15 of Set 13 | solnechnyy
# Processing Record 16 of Set 13 | yokadouma
# Processing Record 17 of Set 13 | qaqortoq
# Processing Record 18 of Set 13 | natal
# Processing Record 19 of Set 13 | mizan teferi
# Processing Record 20 of Set 13 | kaili
# Processing Record 21 of Set 13 | mantua
# Processing Record 22 of Set 13 | manadhoo
# Processing Record 23 of Set 13 | chancay
# Processing Record 24 of Set 13 | qena
# Processing Record 25 of Set 13 | warrnambool
# Processing Record 26 of Set 13 | tiznit
# Processing Record 27 of Set 13 | kidal
# Processing Record 28 of Set 13 | miri
# Processing Record 29 of Set 13 | dossor
# Processing Record 30 of Set 13 | mortka
# Processing Record 31 of Set 13 | arona
# Processing Record 32 of Set 13 | tourlaville
# Processing Record 33 of Set 13 | metu
# Processing Record 34 of Set 13 | sao francisco de assis
# Processing Record 35 of Set 13 | ternate
# Processing Record 36 of Set 13 | ekibastuz
# Processing Record 37 of Set 13 | san quintin
# Processing Record 38 of Set 13 | xianshuigu
# Processing Record 39 of Set 13 | tezu
# Processing Record 40 of Set 13 | adrar
# Processing Record 41 of Set 13 | marawi
# Processing Record 42 of Set 13 | port hedland
# Processing Record 43 of Set 13 | huntsville
# Processing Record 44 of Set 13 | abonnema
# Processing Record 45 of Set 13 | harrisburg
# Processing Record 46 of Set 13 | cherskiy
# Processing Record 47 of Set 13 | sorland
# Processing Record 48 of Set 13 | tinskoy
# Processing Record 49 of Set 13 | salym
# Processing Record 50 of Set 13 | gaspe
# Processing Record 1 of Set 14 | sao raimundo das mangabeiras
# Processing Record 2 of Set 14 | gostovici
# Processing Record 3 of Set 14 | huanuco
# Processing Record 4 of Set 14 | nemuro
# Processing Record 5 of Set 14 | aleksandrov gay
# Processing Record 6 of Set 14 | tondon
# Processing Record 7 of Set 14 | simbahan
# Processing Record 8 of Set 14 | luanda
# Processing Record 9 of Set 14 | naini tal
# Processing Record 10 of Set 14 | cacoal
# Processing Record 11 of Set 14 | havoysund
# Processing Record 12 of Set 14 | vanimo
# Processing Record 13 of Set 14 | margate
# Processing Record 14 of Set 14 | sibolga
# Processing Record 15 of Set 14 | concordia
# Processing Record 16 of Set 14 | sobolevo
# Processing Record 17 of Set 14 | prainha
# Processing Record 18 of Set 14 | omboue
# Processing Record 19 of Set 14 | hasaki
# Processing Record 20 of Set 14 | neiafu
# Processing Record 21 of Set 14 | yantal
# Processing Record 22 of Set 14 | maragogi
# Processing Record 23 of Set 14 | natchez
# Processing Record 24 of Set 14 | berlevag
# Processing Record 25 of Set 14 | la ronge
# Processing Record 26 of Set 14 | lieksa
# Processing Record 27 of Set 14 | mbekenyera
# Processing Record 28 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 29 of Set 14 | mananara
# Processing Record 30 of Set 14 | capitao poco
# Processing Record 31 of Set 14 | bereda
# Processing Record 32 of Set 14 | port-gentil
# Processing Record 33 of Set 14 | berdigestyakh
# Processing Record 34 of Set 14 | verkhnyaya khava
# Processing Record 35 of Set 14 | awbari
# Processing Record 36 of Set 14 | zhangye
# Processing Record 37 of Set 14 | fountain hills
# Processing Record 38 of Set 14 | sept-iles
# Processing Record 39 of Set 14 | douglas
# Processing Record 40 of Set 14 | shar
# Processing Record 41 of Set 14 | san rafael
# Processing Record 42 of Set 14 | jingdezhen
# Processing Record 43 of Set 14 | baruun-urt
# Processing Record 44 of Set 14 | piacabucu
# Processing Record 45 of Set 14 | parintins
# Processing Record 46 of Set 14 | kenora
# Processing Record 47 of Set 14 | jiuquan
# Processing Record 48 of Set 14 | derzhavinsk
# Processing Record 49 of Set 14 | boyolangu
# Processing Record 50 of Set 14 | nuuk
# Processing Record 1 of Set 15 | perth
# Processing Record 2 of Set 15 | morant bay
# Processing Record 3 of Set 15 | bougouni
# Processing Record 4 of Set 15 | lambari
# Processing Record 5 of Set 15 | port blair
# Processing Record 6 of Set 15 | lithgow
# Processing Record 7 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 15 | mananjary
# Processing Record 9 of Set 15 | acarau
# Processing Record 10 of Set 15 | badiraguato
# Processing Record 11 of Set 15 | anchorage
# Processing Record 12 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 15 | kaeo
# Processing Record 14 of Set 15 | nong kung si
# Processing Record 15 of Set 15 | yelizovo
# Processing Record 16 of Set 15 | bambanglipuro
# Processing Record 17 of Set 15 | energetik
# Processing Record 18 of Set 15 | hvide sande
# Processing Record 19 of Set 15 | mapiri
# Processing Record 20 of Set 15 | mubende
# Processing Record 21 of Set 15 | college
# Processing Record 22 of Set 15 | khorixas
# Processing Record 23 of Set 15 | huilong
# Processing Record 24 of Set 15 | lima
# Processing Record 25 of Set 15 | kieta
# Processing Record 26 of Set 15 | katobu
# Processing Record 27 of Set 15 | norrtalje
# Processing Record 28 of Set 15 | chifeng
# Processing Record 29 of Set 15 | matagami
# Processing Record 30 of Set 15 | mastic beach
# Processing Record 31 of Set 15 | egvekinot
# Processing Record 32 of Set 15 | oyama
# Processing Record 33 of Set 15 | balkhash
# Processing Record 34 of Set 15 | mehamn
# Processing Record 35 of Set 15 | camana
# -----------------------------
# Data Retrieval Complete
# -----------------------------
#            City      Lat       Lng  Max Temp Weather Description  Humidity  \
# 0    Port Hardy  50.6996 -127.4199     48.20       broken clouds        93
# 1         Sembe   1.6481   14.5806     69.21       broken clouds        98
# 2      Katsuura  35.1333  140.3000     68.04           clear sky        53
# 3         Vaini -21.2000 -175.2000     78.96       broken clouds       100
# 4  Constitucion -35.3333  -72.4167     51.30           clear sky        61
# 5      Luderitz -26.6481   15.1594     58.01          few clouds        74
# 6   Provideniya  64.3833 -173.3000     11.46       broken clouds        81
# 7   Port Alfred -33.5906   26.8910     65.64     overcast clouds        83
# 8      Alvaraes  -3.2208  -64.8042     73.99     overcast clouds        97
# 9        Barrow  71.2906 -156.7887     15.82           clear sky        73
#
#    Cloudiness  Wind Speed Country                 Date
# 0          75        6.91      CA  2021-11-05 04:15:46
# 1          73        0.78      CG  2021-11-05 04:19:56
# 2           2        7.18      JP  2021-11-05 04:19:57
# 3          75        8.05      TO  2021-11-05 04:19:57
# 4           0        9.46      CL  2021-11-05 04:19:58
# 5          13       13.00      NA  2021-11-05 04:19:59
# 6          51        9.75      RU  2021-11-05 04:19:59
# 7          97        5.64      ZA  2021-11-05 04:16:14
# 8          90        0.38      BR  2021-11-05 04:20:00
# 9           1       16.11      US  2021-11-05 04:15:02
